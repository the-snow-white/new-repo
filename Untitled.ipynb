# %%
import cv2
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
image = cv2.imread('/media/zablon/Transcend/ml project/Project/IMG_20210318_135127.jpg') 
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
image.shape
# Out:
# (3456, 4608, 3)

# %%
image[0][0]
# Out:
# array([ 9,  8, 10], dtype=uint8)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print("Original Image:")
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
plt.show()
gray.shape
# Out:
# Original Image:
# (3456, 4608)

# %%
import numpy as np
data = np.array(gray)
flattened = data.flatten()
flattened.shape
# Out:
# (15925248,)

# %%
flattened
# Out:
# array([ 9,  9, 15, ..., 56, 60, 59], dtype=uint8)

# %%
mat_y = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])
mat_x = np.array([[ -1, 0, 1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])
  
filtered_image = cv2.filter2D(gray, -1, mat_y)
plt.imshow(filtered_image, cmap='gray')

# %%
filtered_image = cv2.filter2D(gray, -1, mat_x)
plt.imshow(filtered_image, cmap='gray')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as fn

# %%
import numpy as np
filter_vals = np.array([[-1, -1, 1, 2], [-1, -1, 1, 0], [-1, -1, 1, 1], [-1, -1, 1, 1]])
print("Filter shape: ", filter_vals.shape)
# Out:
# Filter shape:  (4, 4)

# %%
class Net(nn.Module):
    def __init__(self, weight):

# %%
class Net(nn.Module):
 
 def __init__(self, weight): #Declaring a constructor to initialize the class variables
     super(Net, self).__init__()
 # Initializes the weights of the convolutional layer to be the weights of the 4 defined filters
     k_height, k_width = weight.shape[2:]
 # Assumes there are 4 grayscale filters; We declare the CNN layer here. Size of the kernel equals size of the filter
 # Usually the Kernels are smaller in size
     self.conv = nn.Conv2d(1, 4, kernel_size=(k_height, k_width), bias=False)
     self.conv.weight = torch.nn.Parameter(weight)
 
 def forward(self, x):
 # Calculates the output of a convolutional layer pre- and post-activation
     conv_x = self.conv(x)
     activated_x = fn.relu(conv_x)
# Returns both layers
     return conv_x, activated_x
# Instantiate the model and set the weights
weight = torch.from_numpy(filters).unsqueeze(1).type(torch.FloatTensor)
model = Net(weight)
# Print out the layer in the network
print(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57789/20384551.py in <module>
#      17      return conv_x, activated_x
#      18 # Instantiate the model and set the weights
# ---> 19 weight = torch.from_numpy(filters).unsqueeze(1).type(torch.FloatTensor)
#      20 model = Net(weight)
#      21 # Print out the layer in the network
#
# NameError: name 'filters' is not defined
